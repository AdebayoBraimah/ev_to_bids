# %%
import os
import sys
import pandas as pd

# %%
# Pandas see all rows/columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# File variables
end = "end_001_001_bart.txt"
inf = "inflate_001_001_bart.txt"
iti = "iti_001_001_bart.txt"
pop = "pop_001_001_bart.txt"
pmp = "pump_001_001_bart.txt"
thk = "think_001_001_bart.txt"
wat = "wait_001_001_bart.txt"
win = "win_001_001_bart.txt"

# %%
def fsl_stim_to_df(stim,trial_type="trial_type"):
    '''
    working doc-string
    '''
    df = pd.read_csv(stim,header=None,sep="\t")
    df.columns = ["ONSET","DURATION","INTENSITY"]
    df['TRIAL_TYPE'] = f"{trial_type}"
    return df

# %%
df_iti = fsl_stim_to_df(iti,"ITI")
df_pop = fsl_stim_to_df(pop,"Pop")

# %%
# frames = [df_iti,df_pop]

# %%
# df_1 = pd.concat(frames,ignore_index=False)
# df_1.sort_values(by=['ONSET'])

# %%
# args = [df_iti,df_pop]
# frames = []
# for arg in args:
#     frames+=[arg]
# df_1 = pd.concat(frames,ignore_index=False); df_1
# # df_1.sort_values(by=['ONSET'])

# %%
# df_1 = pd.concat(frames,ignore_index=False)
# df_1.sort_values(by=['ONSET'])

# %%
def create_bids_df(*args):
    '''
    working doc-string
    '''
    frames = []
    for arg in args:
        frames+=[arg]
    df = pd.concat(frames,ignore_index=True)
    return df.sort_values(by=['ONSET'])

# %%
args = [df_iti,df_pop]
create_bids_df(*args)
# Out:
#        ONSET  DURATION  INTENSITY TRIAL_TYPE
# 0     21.102       3.5        1.0        ITI
# 1     44.578       3.0        1.0        ITI
# 2     69.103       6.0        1.0        ITI
# 3     94.088       1.0        1.0        ITI
# 4    114.603       4.5        1.0        ITI
# 5    137.093       6.5        1.0        ITI
# 60   158.519       4.0        1.0        Pop
# 6    162.599       5.5        1.0        ITI
# 61   186.024       2.0        1.0        Pop
# 7    188.102       2.5        1.0        ITI
# 8    222.599       4.5        1.0        ITI
# 9    248.601       7.0        1.0        ITI
# 10   276.591       5.0        1.0        ITI
# 62   303.523       2.0        1.0        Pop
# 11   305.606       4.0        1.0        ITI
# 63   327.522       2.5        1.0        Pop
# 12   330.079       3.5        1.0        ITI
# 64   350.522       2.5        1.0        Pop
# 13   353.087       3.0        1.0        ITI
# 14   373.099       2.0        1.0        ITI
# 15   391.095       5.5        1.0        ITI
# 16   418.100       4.0        1.0        ITI
# 17   439.095       2.5        1.0        ITI
# 18   460.600       1.5        1.0        ITI
# 19   487.092       5.0        1.0        ITI
# 20   657.603       3.5        1.0        ITI
# 21   681.641       5.5        1.0        ITI
# 22   704.117       3.5        1.0        ITI
# 23   725.612       4.0        1.0        ITI
# 65   751.049       5.0        1.0        Pop
# 24   756.112       4.5        1.0        ITI
# 25   776.620       2.0        1.0        ITI
# 26   796.132       5.0        1.0        ITI
# 66   819.055       4.5        1.0        Pop
# 27   823.620       1.0        1.0        ITI
# 28   846.624       3.0        1.0        ITI
# 29   871.132       2.5        1.0        ITI
# 30   892.126       6.5        1.0        ITI
# 67   917.054       1.0        1.0        Pop
# 31   918.113       7.0        1.0        ITI
# 68   941.553       2.5        1.0        Pop
# 32   944.118       4.5        1.0        ITI
# 69   964.558       3.5        1.0        Pop
# 33   968.193       2.5        1.0        ITI
# 34   993.134       4.0        1.0        ITI
# 35  1016.605       1.5        1.0        ITI
# 36  1040.096       6.0        1.0        ITI
# 37  1063.122       5.5        1.0        ITI
# 38  1093.121       3.0        1.0        ITI
# 39  1114.116       5.0        1.0        ITI
# 40  1296.166       5.5        1.0        ITI
# 41  1318.654       6.0        1.0        ITI
# 42  1343.144       4.0        1.0        ITI
# 43  1369.651       5.5        1.0        ITI
# 44  1395.668       3.5        1.0        ITI
# 45  1417.196       5.0        1.0        ITI
# 70  1441.587       2.5        1.0        Pop
# 46  1444.167       3.0        1.0        ITI
# 71  1467.586       4.5        1.0        Pop
# 47  1472.171       2.0        1.0        ITI
# 48  1495.159       2.5        1.0        ITI
# 49  1515.139       3.5        1.0        ITI
# 50  1536.150       1.0        1.0        ITI
# 72  1550.585       5.0        1.0        Pop
# 51  1555.646       7.0        1.0        ITI
# 73  1579.584       3.0        1.0        Pop
# 52  1582.648       5.0        1.0        ITI
# 74  1606.084       3.5        1.0        Pop
# 53  1609.652       2.5        1.0        ITI
# 54  1631.659       1.5        1.0        ITI
# 55  1655.150       6.5        1.0        ITI
# 56  1682.156       3.0        1.0        ITI
# 57  1703.150       4.5        1.0        ITI
# 58  1730.152       4.5        1.0        ITI
# 59  1754.157       4.0        1.0        ITI

# %%
kwargs = {
    "End":end,
    "Inflate":inf,
    "Think":thk,
    "Pop":pop,
    "ITI":iti,
    "Win":win
}

# %%
frames = []
for key,value in kwargs.items():
    tmp_frame = fsl_stim_to_df(stim=value,trial_type=key)
    frames.append(tmp_frame)

# %%
len(frames)
# Out:
# 5

# %%
df = create_bids_df(*frames)

# %%
df.drop(["INTENSITY"],axis=1)
# Out:
#         ONSET  DURATION TRIAL_TYPE
# 3      15.516     4.000    Inflate
# 138    19.519     1.500        Win
# 78     21.102     3.500        ITI
# 4      38.016     4.000    Inflate
# 139    42.018     2.500        Win
# 79     44.578     3.000        ITI
# 5      62.016     2.000    Inflate
# 140    64.019     5.000        Win
# 80     69.103     6.000        ITI
# 6      88.016     5.000    Inflate
# 141    93.018     1.000        Win
# 81     94.088     1.000        ITI
# 7     107.516     2.500    Inflate
# 142   110.019     4.500        Win
# 82    114.603     4.500        ITI
# 8     131.516     2.500    Inflate
# 143   134.019     3.000        Win
# 83    137.093     6.500        ITI
# 9     152.517     6.000    Inflate
# 63    158.519     4.000        Pop
# 84    162.599     5.500        ITI
# 10    182.516     3.500    Inflate
# 64    186.024     2.000        Pop
# 85    188.102     2.500        ITI
# 11    215.016     4.000    Inflate
# 144   219.019     3.500        Win
# 86    222.599     4.500        ITI
# 12    243.516     3.500    Inflate
# 145   247.019     1.500        Win
# 87    248.601     7.000        ITI
# 13    266.016     5.500    Inflate
# 146   271.518     5.000        Win
# 88    276.591     5.000        ITI
# 14    298.517     5.000    Inflate
# 65    303.523     2.000        Pop
# 89    305.606     4.000        ITI
# 15    323.016     4.500    Inflate
# 66    327.522     2.500        Pop
# 90    330.079     3.500        ITI
# 16    347.516     3.000    Inflate
# 67    350.522     2.500        Pop
# 91    353.087     3.000        ITI
# 17    366.016     4.000    Inflate
# 147   370.019     3.000        Win
# 92    373.099     2.000        ITI
# 18    386.517     2.000    Inflate
# 148   388.519     2.500        Win
# 93    391.095     5.500        ITI
# 19    410.016     4.500    Inflate
# 149   414.519     3.500        Win
# 94    418.100     4.000        ITI
# 20    431.516     3.000    Inflate
# 150   434.519     4.500        Win
# 95    439.095     2.500        ITI
# 21    453.516     6.000    Inflate
# 151   459.519     1.000        Win
# 96    460.600     1.500        ITI
# 22    476.516     5.500    Inflate
# 152   482.019     5.000        Win
# 97    487.092     5.000        ITI
# 0     495.031    43.985        End
# 23    650.547     3.500    Inflate
# 153   654.050     3.500        Win
# 98    657.603     3.500        ITI
# 24    675.547     4.000    Inflate
# 154   679.549     2.000        Win
# 99    681.641     5.500        ITI
# 25    699.047     2.500    Inflate
# 155   701.550     2.500        Win
# 100   704.117     3.500        ITI
# 26    717.047     3.500    Inflate
# 156   720.550     5.000        Win
# 101   725.612     4.000        ITI
# 27    745.047     6.000    Inflate
# 68    751.049     5.000        Pop
# 102   756.112     4.500        ITI
# 28    771.047     3.000    Inflate
# 157   774.050     2.500        Win
# 103   776.620     2.000        ITI
# 29    789.047     4.000    Inflate
# 158   793.049     3.000        Win
# 104   796.132     5.000        ITI
# 30    813.547     5.500    Inflate
# 69    819.055     4.500        Pop
# 105   823.620     1.000        ITI
# 31    841.547     4.000    Inflate
# 159   845.550     1.000        Win
# 106   846.624     3.000        ITI
# 32    864.047     5.000    Inflate
# 160   869.049     2.000        Win
# 107   871.132     2.500        ITI
# 33    888.547     2.000    Inflate
# 161   890.549     1.500        Win
# 108   892.126     6.500        ITI
# 34    912.547     4.500    Inflate
# 70    917.054     1.000        Pop
# 109   918.113     7.000        ITI
# 35    936.547     5.000    Inflate
# 71    941.553     2.500        Pop
# 110   944.118     4.500        ITI
# 36    960.047     4.500    Inflate
# 72    964.558     3.500        Pop
# 111   968.193     2.500        ITI
# 37    985.047     3.000    Inflate
# 162   988.050     5.000        Win
# 112   993.134     4.000        ITI
# 38   1011.047     4.000    Inflate
# 163  1015.050     1.500        Win
# 113  1016.605     1.500        ITI
# 39   1031.047     6.000    Inflate
# 164  1037.050     3.000        Win
# 114  1040.096     6.000        ITI
# 40   1056.547     2.500    Inflate
# 165  1059.050     4.000        Win
# 115  1063.122     5.500        ITI
# 41   1085.047     5.500    Inflate
# 166  1090.550     2.500        Win
# 116  1093.121     3.000        ITI
# 42   1107.547     2.000    Inflate
# 167  1109.550     4.500        Win
# 117  1114.116     5.000        ITI
# 1    1122.056    55.991        End
# 43   1288.578     2.500    Inflate
# 168  1291.080     5.000        Win
# 118  1296.166     5.500        ITI
# 44   1312.079     5.000    Inflate
# 169  1317.081     1.500        Win
# 119  1318.654     6.000        ITI
# 45   1338.079     3.500    Inflate
# 170  1341.581     1.500        Win
# 120  1343.144     4.000        ITI
# 46   1362.578     2.500    Inflate
# 171  1365.081     4.500        Win
# 121  1369.651     5.500        ITI
# 47   1389.078     5.500    Inflate
# 172  1394.581     1.000        Win
# 122  1395.668     3.500        ITI
# 48   1410.078     4.500    Inflate
# 173  1414.582     2.500        Win
# 123  1417.196     5.000        ITI
# 49   1437.578     4.000    Inflate
# 73   1441.587     2.500        Pop
# 124  1444.167     3.000        ITI
# 50   1461.578     6.000    Inflate
# 74   1467.586     4.500        Pop
# 125  1472.171     2.000        ITI
# 51   1488.578     5.500    Inflate
# 174  1494.080     1.000        Win
# 126  1495.159     2.500        ITI
# 52   1509.078     3.000    Inflate
# 175  1512.081     3.000        Win
# 127  1515.139     3.500        ITI
# 53   1528.578     5.000    Inflate
# 176  1533.581     2.500        Win
# 128  1536.150     1.000        ITI
# 54   1548.578     2.000    Inflate
# 75   1550.585     5.000        Pop
# 129  1555.646     7.000        ITI
# 55   1576.578     3.000    Inflate
# 76   1579.584     3.000        Pop
# 130  1582.648     5.000        ITI
# 56   1600.079     6.000    Inflate
# 77   1606.084     3.500        Pop
# 131  1609.652     2.500        ITI
# 57   1625.078     4.500    Inflate
# 177  1629.580     2.000        Win
# 132  1631.659     1.500        ITI
# 58   1648.578     4.000    Inflate
# 178  1652.581     2.500        Win
# 133  1655.150     6.500        ITI
# 59   1674.078     4.000    Inflate
# 179  1678.080     4.000        Win
# 134  1682.156     3.000        ITI
# 60   1696.078     2.000    Inflate
# 180  1698.081     5.000        Win
# 135  1703.150     4.500        ITI
# 61   1722.579     4.000    Inflate
# 181  1726.581     3.500        Win
# 136  1730.152     4.500        ITI
# 62   1748.579     3.500    Inflate
# 182  1752.080     2.000        Win
# 137  1754.157     4.000        ITI
# 2    1761.084    55.994        End

# %%
def create_bids_evs(**kwargs):
    '''
    working doc-string
    '''
    frames = []
    for key,value in kwargs.items():
        tmp_frame = fsl_stim_to_df(stim=value,trial_type=key)
        frames.append(tmp_frame)
    df = create_bids_df(*frames)
    return df.drop(["INTENSITY"],axis=1)

# %%
create_bids_evs(**kwargs)
# Out:
#         ONSET  DURATION TRIAL_TYPE
# 63      0.042     4.500      Think
# 3      15.516     4.000    Inflate
# 198    19.519     1.500        Win
# 138    21.102     3.500        ITI
# 64     24.548     5.000      Think
# 4      38.016     4.000    Inflate
# 199    42.018     2.500        Win
# 139    44.578     3.000        ITI
# 65     47.540     5.000      Think
# 5      62.016     2.000    Inflate
# 200    64.019     5.000        Win
# 140    69.103     6.000        ITI
# 66     75.043     5.500      Think
# 6      88.016     5.000    Inflate
# 201    93.018     1.000        Win
# 141    94.088     1.000        ITI
# 67     95.037     3.000      Think
# 7     107.516     2.500    Inflate
# 202   110.019     4.500        Win
# 142   114.603     4.500        ITI
# 68    119.044     4.000      Think
# 8     131.516     2.500    Inflate
# 203   134.019     3.000        Win
# 143   137.093     6.500        ITI
# 69    143.550     2.000      Think
# 9     152.517     6.000    Inflate
# 123   158.519     4.000        Pop
# 144   162.599     5.500        ITI
# 70    168.040     4.000      Think
# 10    182.516     3.500    Inflate
# 124   186.024     2.000        Pop
# 145   188.102     2.500        ITI
# 71    202.569     4.000      Think
# 11    215.016     4.000    Inflate
# 204   219.019     3.500        Win
# 146   222.599     4.500        ITI
# 72    227.042     6.000      Think
# 12    243.516     3.500    Inflate
# 205   247.019     1.500        Win
# 147   248.601     7.000        ITI
# 73    255.544     2.500      Think
# 13    266.016     5.500    Inflate
# 206   271.518     5.000        Win
# 148   276.591     5.000        ITI
# 74    281.548     6.000      Think
# 14    298.517     5.000    Inflate
# 125   303.523     2.000        Pop
# 149   305.606     4.000        ITI
# 75    309.551     3.500      Think
# 15    323.016     4.500    Inflate
# 126   327.522     2.500        Pop
# 150   330.079     3.500        ITI
# 76    333.541     5.500      Think
# 16    347.516     3.000    Inflate
# 127   350.522     2.500        Pop
# 151   353.087     3.000        ITI
# 77    356.049     2.000      Think
# 17    366.016     4.000    Inflate
# 207   370.019     3.000        Win
# 152   373.099     2.000        ITI
# 78    375.045     4.000      Think
# 18    386.517     2.000    Inflate
# 208   388.519     2.500        Win
# 153   391.095     5.500        ITI
# 79    396.538     4.500      Think
# 19    410.016     4.500    Inflate
# 209   414.519     3.500        Win
# 154   418.100     4.000        ITI
# 80    422.043     2.500      Think
# 20    431.516     3.000    Inflate
# 210   434.519     4.500        Win
# 155   439.095     2.500        ITI
# 81    441.538     3.000      Think
# 21    453.516     6.000    Inflate
# 211   459.519     1.000        Win
# 156   460.600     1.500        ITI
# 82    462.049     3.500      Think
# 22    476.516     5.500    Inflate
# 212   482.019     5.000        Win
# 157   487.092     5.000        ITI
# 0     495.031    43.985        End
# 83    639.070     4.000      Think
# 23    650.547     3.500    Inflate
# 213   654.050     3.500        Win
# 158   657.603     3.500        ITI
# 84    661.079     5.000      Think
# 24    675.547     4.000    Inflate
# 214   679.549     2.000        Win
# 159   681.641     5.500        ITI
# 85    687.067     2.500      Think
# 25    699.047     2.500    Inflate
# 215   701.550     2.500        Win
# 160   704.117     3.500        ITI
# 86    707.578     2.000      Think
# 26    717.047     3.500    Inflate
# 216   720.550     5.000        Win
# 161   725.612     4.000        ITI
# 87    729.570     5.000      Think
# 27    745.047     6.000    Inflate
# 128   751.049     5.000        Pop
# 162   756.112     4.500        ITI
# 88    760.569     3.500      Think
# 28    771.047     3.000    Inflate
# 217   774.050     2.500        Win
# 163   776.620     2.000        ITI
# 89    778.583     2.000      Think
# 29    789.047     4.000    Inflate
# 218   793.049     3.000        Win
# 164   796.132     5.000        ITI
# 90    801.075     4.500      Think
# 30    813.547     5.500    Inflate
# 129   819.055     4.500        Pop
# 165   823.620     1.000        ITI
# 91    824.582     6.000      Think
# 31    841.547     4.000    Inflate
# 219   845.550     1.000        Win
# 166   846.624     3.000        ITI
# 92    849.571     4.000      Think
# 32    864.047     5.000    Inflate
# 220   869.049     2.000        Win
# 167   871.132     2.500        ITI
# 93    873.578     4.000      Think
# 33    888.547     2.000    Inflate
# 221   890.549     1.500        Win
# 168   892.126     6.500        ITI
# 94    898.567     5.500      Think
# 34    912.547     4.500    Inflate
# 130   917.054     1.000        Pop
# 169   918.113     7.000        ITI
# 95    925.071     3.000      Think
# 35    936.547     5.000    Inflate
# 131   941.553     2.500        Pop
# 170   944.118     4.500        ITI
# 96    948.579     2.500      Think
# 36    960.047     4.500    Inflate
# 132   964.558     3.500        Pop
# 171   968.193     2.500        ITI
# 97    970.571     4.500      Think
# 37    985.047     3.000    Inflate
# 222   988.050     5.000        Win
# 172   993.134     4.000        ITI
# 98    997.075     6.000      Think
# 38   1011.047     4.000    Inflate
# 223  1015.050     1.500        Win
# 173  1016.605     1.500        ITI
# 99   1018.069     4.000      Think
# 39   1031.047     6.000    Inflate
# 224  1037.050     3.000        Win
# 174  1040.096     6.000        ITI
# 100  1046.071     3.500      Think
# 40   1056.547     2.500    Inflate
# 225  1059.050     4.000        Win
# 175  1063.122     5.500        ITI
# 101  1068.580     5.500      Think
# 41   1085.047     5.500    Inflate
# 226  1090.550     2.500        Win
# 176  1093.121     3.000        ITI
# 102  1096.083     3.000      Think
# 42   1107.547     2.000    Inflate
# 227  1109.550     4.500        Win
# 177  1114.116     5.000        ITI
# 1    1122.056    55.991        End
# 103  1278.098     2.500      Think
# 43   1288.578     2.500    Inflate
# 228  1291.080     5.000        Win
# 178  1296.166     5.500        ITI
# 104  1301.606     3.000      Think
# 44   1312.079     5.000    Inflate
# 229  1317.081     1.500        Win
# 179  1318.654     6.000        ITI
# 105  1324.614     5.500      Think
# 45   1338.079     3.500    Inflate
# 230  1341.581     1.500        Win
# 180  1343.144     4.000        ITI
# 106  1347.106     5.000      Think
# 46   1362.578     2.500    Inflate
# 231  1365.081     4.500        Win
# 181  1369.651     5.500        ITI
# 107  1375.108     3.000      Think
# 47   1389.078     5.500    Inflate
# 232  1394.581     1.000        Win
# 182  1395.668     3.500        ITI
# 108  1399.098     2.000      Think
# 48   1410.078     4.500    Inflate
# 233  1414.582     2.500        Win
# 183  1417.196     5.000        ITI
# 109  1422.106     6.000      Think
# 49   1437.578     4.000    Inflate
# 133  1441.587     2.500        Pop
# 184  1444.167     3.000        ITI
# 110  1447.112     3.500      Think
# 50   1461.578     6.000    Inflate
# 134  1467.586     4.500        Pop
# 185  1472.171     2.000        ITI
# 111  1474.099     6.000      Think
# 51   1488.578     5.500    Inflate
# 234  1494.080     1.000        Win
# 186  1495.159     2.500        ITI
# 112  1497.606     4.500      Think
# 52   1509.078     3.000    Inflate
# 235  1512.081     3.000        Win
# 187  1515.139     3.500        ITI
# 113  1518.600     2.500      Think
# 53   1528.578     5.000    Inflate
# 236  1533.581     2.500        Win
# 188  1536.150     1.000        ITI
# 114  1537.113     2.000      Think
# 54   1548.578     2.000    Inflate
# 135  1550.585     5.000        Pop
# 189  1555.646     7.000        ITI
# 115  1562.601     5.000      Think
# 55   1576.578     3.000    Inflate
# 136  1579.584     3.000        Pop
# 190  1582.648     5.000        ITI
# 116  1587.607     4.000      Think
# 56   1600.079     6.000    Inflate
# 137  1606.084     3.500        Pop
# 191  1609.652     2.500        ITI
# 117  1612.113     4.500      Think
# 57   1625.078     4.500    Inflate
# 237  1629.580     2.000        Win
# 192  1631.659     1.500        ITI
# 118  1633.107     5.500      Think
# 58   1648.578     4.000    Inflate
# 238  1652.581     2.500        Win
# 193  1655.150     6.500        ITI
# 119  1661.609     4.000      Think
# 59   1674.078     4.000    Inflate
# 239  1678.080     4.000        Win
# 194  1682.156     3.000        ITI
# 120  1685.099     4.000      Think
# 60   1696.078     2.000    Inflate
# 240  1698.081     5.000        Win
# 195  1703.150     4.500        ITI
# 121  1707.608     4.000      Think
# 61   1722.579     4.000    Inflate
# 241  1726.581     3.500        Win
# 196  1730.152     4.500        ITI
# 122  1734.611     3.500      Think
# 62   1748.579     3.500    Inflate
# 242  1752.080     2.000        Win
# 197  1754.157     4.000        ITI
# 2    1761.084    55.994        End

# %%
list_1 = ["End","Pop","ITI"]
list_2 = [end,pop,iti]

# %%
data = dict()
for key,value in zip(list_1,list_2):
    tmp_dict = {key:value}
    data.update(tmp_dict)

# %%
data
# Out:
# {'End': 'end_001_001_bart.txt',
#  'Pop': 'pop_001_001_bart.txt',
#  'ITI': 'iti_001_001_bart.txt'}

# %%
def create_bids_tsv(name_args,file_args):
    '''
    working doc-string
    '''
    # Check for equal length of input lists
    if len(name_args) != len(file_args):
        print("Input lists of stimulus and file names are of unequal length.")
        sys.exit(1)
    
    # Contruct data dictionary
    data = dict()
    for key,value in zip(name_args,file_args):
        tmp_dict = {key:value}
        data.update(tmp_dict)
        
    # Construct BIDS EVs (Explanitory Variables)
    df = create_bids_evs(**data)
    return df

# %%
create_bids_tsv(["End","Pop","ITI"],[end,pop,iti])
# Out:
#        ONSET  DURATION TRIAL_TYPE
# 18    21.102     3.500        ITI
# 19    44.578     3.000        ITI
# 20    69.103     6.000        ITI
# 21    94.088     1.000        ITI
# 22   114.603     4.500        ITI
# 23   137.093     6.500        ITI
# 3    158.519     4.000        Pop
# 24   162.599     5.500        ITI
# 4    186.024     2.000        Pop
# 25   188.102     2.500        ITI
# 26   222.599     4.500        ITI
# 27   248.601     7.000        ITI
# 28   276.591     5.000        ITI
# 5    303.523     2.000        Pop
# 29   305.606     4.000        ITI
# 6    327.522     2.500        Pop
# 30   330.079     3.500        ITI
# 7    350.522     2.500        Pop
# 31   353.087     3.000        ITI
# 32   373.099     2.000        ITI
# 33   391.095     5.500        ITI
# 34   418.100     4.000        ITI
# 35   439.095     2.500        ITI
# 36   460.600     1.500        ITI
# 37   487.092     5.000        ITI
# 0    495.031    43.985        End
# 38   657.603     3.500        ITI
# 39   681.641     5.500        ITI
# 40   704.117     3.500        ITI
# 41   725.612     4.000        ITI
# 8    751.049     5.000        Pop
# 42   756.112     4.500        ITI
# 43   776.620     2.000        ITI
# 44   796.132     5.000        ITI
# 9    819.055     4.500        Pop
# 45   823.620     1.000        ITI
# 46   846.624     3.000        ITI
# 47   871.132     2.500        ITI
# 48   892.126     6.500        ITI
# 10   917.054     1.000        Pop
# 49   918.113     7.000        ITI
# 11   941.553     2.500        Pop
# 50   944.118     4.500        ITI
# 12   964.558     3.500        Pop
# 51   968.193     2.500        ITI
# 52   993.134     4.000        ITI
# 53  1016.605     1.500        ITI
# 54  1040.096     6.000        ITI
# 55  1063.122     5.500        ITI
# 56  1093.121     3.000        ITI
# 57  1114.116     5.000        ITI
# 1   1122.056    55.991        End
# 58  1296.166     5.500        ITI
# 59  1318.654     6.000        ITI
# 60  1343.144     4.000        ITI
# 61  1369.651     5.500        ITI
# 62  1395.668     3.500        ITI
# 63  1417.196     5.000        ITI
# 13  1441.587     2.500        Pop
# 64  1444.167     3.000        ITI
# 14  1467.586     4.500        Pop
# 65  1472.171     2.000        ITI
# 66  1495.159     2.500        ITI
# 67  1515.139     3.500        ITI
# 68  1536.150     1.000        ITI
# 15  1550.585     5.000        Pop
# 69  1555.646     7.000        ITI
# 16  1579.584     3.000        Pop
# 70  1582.648     5.000        ITI
# 17  1606.084     3.500        Pop
# 71  1609.652     2.500        ITI
# 72  1631.659     1.500        ITI
# 73  1655.150     6.500        ITI
# 74  1682.156     3.000        ITI
# 75  1703.150     4.500        ITI
# 76  1730.152     4.500        ITI
# 77  1754.157     4.000        ITI
# 2   1761.084    55.994        End
